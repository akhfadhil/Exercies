# %% [markdown]
# # Teori

# %%
# !pip install pillow

# %%
from PIL import Image

# %%
bilstm = Image.open('/content/fani bi-lstm rev.png')

# %%
bilstm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2954x1155>

# %%
type(bilstm)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
bilstm.size #width, height
# Out:
# (2954, 1155)

# %%
bilstm.filename
# Out:
# '/content/fani bi-lstm rev.png'

# %%
bilstm.format_description
# Out:
# 'Portable network graphics'

# %%
bilstm.getcolors
# Out:
# <bound method Image.getcolors of <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2954x1155 at 0x7AE2FE6CA200>>

# %% [markdown]
# crop (x,y,w,h)
# x->w
# y->h

# %%
bilstm.crop((0, 0, 1000, 500))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x500>

# %%
output1 = bilstm.crop((0, 0, 1000, 500))

# %%
bilstm.paste(im=output1, box=(20,20))

# %%
bilstm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2954x1155>

# %% [markdown]
# resize

# %%
bilstm.size
# Out:
# (2954, 1155)

# %%
bilstm.resize((1000, 500))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x500>

# %% [markdown]
# rotate

# %%
bilstm.rotate(135)
# Out:
# <PIL.Image.Image image mode=RGBA size=2954x1155>

# %% [markdown]
# color rgba

# %%
bilstm.putalpha(135)
bilstm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2954x1155>

# %% [markdown]
# # exercise

# %%
wm = Image.open('/content/word_matrix.png')
wm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>

# %%
m = Image.open('/content/mask.png')
m
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
wm.size
# Out:
# (1015, 559)

# %%
m.size
# Out:
# (505, 251)

# %%
m = m.resize((1015, 559))
m
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
m.putalpha(128)
m
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
wm.paste(m, (0,0), )
wm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>
